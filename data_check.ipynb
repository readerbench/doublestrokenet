# %%
import os

len(os.listdir('./KeyDatasets/clean/mobile_users'))
# Out:
# 16630

# %%
len(os.listdir('./KeyDatasets/mobile/pretrain/train/'))
# Out:
# 15000

# %%
len(os.listdir('./KeyDatasets/mobile/finetune/test/'))
# Out:
# 1000
